# %% [markdown]
# <a href="https://colab.research.google.com/github/sravyapitani/FMMLlab/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 11:37:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   147MB/s    in 0.5s
#
# 2024-03-31 11:37:06 (147 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6156   1608.05258v1  We consider log-supermodular models on binary ...  stat
# 30552  1712.05404v1  Detecting and recognizing text in natural scen...    cs
# 38166   1302.4726v1  In this paper, we present a semantic web appro...    cs
# 13640   1405.4894v1  In this paper, we present our investigations o...    cs
# 4333    1410.3751v1  A reliable human skin detection method that is...    cs
# ...             ...                                                ...   ...
# 9660   1511.06036v1  In this paper, we propose a novel technique to...  stat
# 24881   1412.5758v4  We present a domain adaption framework to addr...    cs
# 22381  1605.03027v1  In this paper we propose a new method to predi...  stat
# 37979   0909.4370v2  We provide a systematic study of the problem o...  stat
# 3833   1606.04155v2  Prediction without justification has limited a...    cs
#
#                                                    title  year  \
# 6156   Parameter Learning for Log-supermodular Distri...  2016
# 30552  SEE: Towards Semi-Supervised End-to-End Scene ...  2017
# 38166  An Ontology for Modelling and Supporting the P...  2013
# 13640  Optimization of OFDM radar waveforms using gen...  2014
# 4333   A Fusion Approach for Efficient Human Skin Det...  2014
# ...                                                  ...   ...
# 9660   Stochastic gradient method with accelerated st...  2015
# 24881  Decomposition-Based Domain Adaptation for Real...  2014
# 22381  Destination Prediction by Trajectory Distribut...  2016
# 37979            Rumors in a Network: Who's the Culprit?  2009
# 3833                    Rationalizing Neural Predictions  2016
#
#                                                 keywords
# 6156   [supermodular, variables, probabilistic, densi...
# 30552  [detecting, recognizing, challenging, complete...
# 38166  [modelling, technical, regulatory, documents, ...
# 13640  [investigations, objective, multiobjective, al...
# 4333   [detection, adaptable, different, conditions, ...
# ...                                                  ...
# 9660   [technique, implement, stochastic, beneficial,...
# 24881  [framework, synthetic, demonstrate, challengin...
# 22381  [destination, trajectories, clustering, trajec...
# 37979  [systematic, spreading, construct, estimator, ...
# 3833   [prediction, justification, applicability, jus...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6156     [supermodular, variables, probabilistic, densi...
# 30552    [detecting, recognizing, challenging, complete...
# 38166    [modelling, technical, regulatory, documents, ...
# 13640    [investigations, objective, multiobjective, al...
# 4333     [detection, adaptable, different, conditions, ...
#                                ...
# 20775    [preserving, subsequence, combinatorial, optim...
# 33010    [convolutional, variational, autoencoder, dete...
# 21553    [surrogate, arbitrary, surrogate, classificati...
# 10683    [algorithm, stochastic, monitoring, particular...
# 38868    [describes, converter, implemented, designing,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8684 words.
# Out of those 4622 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ce929d0d-70af-4b87-ab42-4ef44b70f5c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce929d0d-70af-4b87-ab42-4ef44b70f5c5")) {                    Plotly.newPlot(                        "ce929d0d-70af-4b87-ab42-4ef44b70f5c5",                        [{"x":["parameters","intractable","probabilistic","submodular","separable","estimation","interpretations","stochastic","experiments","illustrate","subgradient","parameter","technique","conditional","highlight","optimization","densities","expectation","supermodular","denoising","partition","segmentation","likelihood","variables","flexibility","primarily","combinatorial","distributions","approximation","introduce","feasibility","optimized","recognizing","processing","detection","supervised","detecting","recognizes","challenging","transformer","integrates","recognition","completely","performing","identified","benchmark","competitive","recognize","therefore","documents","technical","experiencing","assessments","supporting","scientific","modelling","phenomenal","particular","currently","automating","techniques","regulations","authoring","industries","regulatory","solutions","optimizations","multiobjective","challenges","different","objective","investigations","procedures","waveforms","algorithms","optimisation","effectiveness","ethnicity","essential","computational","quantitative","comparison","conditions","automatic","knowledge","illumination","adaptable","histogram","qualitative","robustness","efficient","variation","successfully","performance","traditional","information","evaluations","combining","simulations","estimated","heuristic","advantageous","difficult","separately","outperform","implicitly","breakthrough","university","algorithm","programming","convergence","crossover","evolutionary","strategies","manuscript","scenarios","considered","additional","complexity","instances","completeness","alternative","behavioral","unreliable","experimental","contribution","challenge","frameworks","comparatively","processes","contaminated","problematic","artifacts","introduced","versatile","recordings","simulation","generating","correlates","benchmarking","partially","labelings","generalization","assumptions","cognitive","specifically","typically","unrealistic","evaluation","arbitrary","noiseless","facilitating","shortcomings","artificial","available","inventories","experience","situations","regularly","presented","accumulate","effective","relevance","decisions","application","preferences","transport","corresponding","kantorovich","approximates","independent","separation","variational","inference","contributes","increasing","posterior","dimensions","independence","benchmarks","approaches","truncated","posteriors","investigate","applications","independently","saturates","furthermore","distribution","interaction","interchangeability","constraints","symmetries","precedence","comprehensive","generalizations","significantly","demonstrated","establish","numerical"],"y":[238,16,159,6,11,217,8,120,602,68,2,104,239,93,28,331,7,23,0,40,22,218,61,125,37,17,41,104,108,339,28,51,34,279,320,198,69,4,265,5,27,382,44,99,36,193,93,50,140,70,38,2,16,28,24,68,2,292,47,6,340,5,3,3,3,153,9,3,112,722,165,14,34,3,606,19,168,3,72,322,82,109,116,183,335,39,6,15,67,113,422,60,86,878,181,704,48,104,48,63,58,11,141,31,102,15,3,12,821,133,115,8,64,97,10,84,128,116,232,99,16,89,22,10,378,81,160,35,6,118,3,9,23,131,8,8,75,110,5,12,45,1,116,58,49,173,102,8,224,91,3,8,14,122,279,2,34,52,4,192,7,233,33,50,236,40,12,121,1,11,117,24,46,203,8,99,38,31,28,96,451,8,5,154,426,31,1,186,200,73,2,143,7,2,80,8,264,84,51,80],"type":"bar"},{"x":["parameters","intractable","probabilistic","submodular","separable","estimation","interp ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4622,), (4622, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.815

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style=''>Load</span> <span style='background-color:rgba(0, 255, 0, 0.36000000000000004);'>Balancing</span> <span style=''>A</span> <span style=''>Study</span> <span style=''>in</span> <span style=''>Multi</span> <span style=''>Agent</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>process</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>agent</span> <span style='background-color:rgba(0, 255, 0, 0.4451612903225806);'>reinforcement</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>load</span> <span style='background-color:rgba(0, 255, 0, 0.36000000000000004);'>balancing</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>system</span> <span style=''>without</span> <span style=''>use</span> <span style=''>of</span> <span style=''>either</span> <span style=''>central</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>coordination</span> <span style=''>or</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.3863636363636364);'>communication</span> <span style=''>We</span> <span style=''>first</span> <span style=''>define</span> <span style=''>a</span> <span style=''>precise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>in</span> <span style=''>which</span> <span style=''>to</span> <span style=''>study</span> <span style=''>adaptive</span> <span style=''>load</span> <span style='background-color:rgba(0, 255, 0, 0.36000000000000004);'>balancing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>features</span> <span style=''>of</span> <span style=''>which</span> <span style=''>are</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3766233766233766);'>stochastic</span> <span style=''>nature</span> <span style=''>and</span> <span style=''>the</span> <span style=''>purely</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3460803059273423);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>agents</span> <span style=''>Given</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>we</span> <span style=''>show</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>illuminating</span> <span style=''>results</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>interplay</span> <span style=''>between</span> <span style=''>basic</span> <span style=''>adaptive</span> <span style=''>behavior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>and</span> <span style=''>their</span> <span style=''>effect</span> <span style=''>on</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style=''>We</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>adaptive</span> <span style=''>load</span> <span style='background-color:rgba(0, 255, 0, 0.36000000000000004);'>balancing</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>populations</span> <span style=''>and</span> <span style=''>address</span> <span style=''>the</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Finding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Differentially</span> <span style=''>Covarying</span> <span style=''>Needles</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Temporally</span> <span style=''>Evolving</span> <span style=''>Haystack</span> <span style=''>A</span> <span style=''>Scan</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Perspective</span> <br/><br/><span style=''>Recent</span> <span style=''>results</span> <span style=''>in</span> <span style=''>coupled</span> <span style=''>or</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>offer</span> <span style=''>schemes</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>between</span> <span style=''>features</span> <span style=''>when</span> <span style=''>the</span> <span style=''>data</span> <span style=''>come</span> <span style=''>from</span> <span style=''>related</span> <span style=''>(but</span> <span style=''>distinct)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>longitudinal</span> <span style=''>sources</span> <span style=''>A</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>these</span> <span style=''>ideas</span> <span style=''>is</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>group</span> <span style=''>level</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differences</span> <span style=''>ie</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>if</span> <span style=''>trends</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>objects</span> <span style=''>(eg</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>matrices)</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>across</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disparate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>(eg</span> <span style=''>gender</span> <span style=''>or</span> <span style=''>disease)</span> <span style=''>Often</span> <span style=''>poor</span> <span style=''>effect</span> <span style=''>sizes</span> <span style=''>make</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detecting</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differential</span> <span style=''>signal</span> <span style=''>over</span> <span style=''>the</span> <span style=''>full</span> <span style=''>set</span> <span style=''>of</span> <span style=''>features</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>for</span> <span style=''>example</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>between</span> <span style=''>only</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>features</span> <span style=''>may</span> <span style=''>manifest</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differently</span> <span style=''>across</span> <span style=''>groups</span> <span style=''>In</span> <span style=''>this</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Short</span> <span style='background-color:rgba(0, 255, 0, 0.3863636363636364);'>Communication</span> <span style=''>on</span> <span style=''>QUIST</span> <span style=''>A</span> <span style=''>Quick</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>short</span> <span style='background-color:rgba(0, 255, 0, 0.3863636363636364);'>communication</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>quick</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>(QUIST)</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style=''>sorting</span> <span style=''>QUIST</span> <span style=''>is</span> <span style=''>a</span> <span style=''>poly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>logarithmic</span> <span style=''>divisive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>does</span> <span style=''>not</span> <span style=''>assume</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>andor</span> <span style=''>the</span> <span style=''>cluster</span> <span style=''>size</span> <span style=''>to</span> <span style=''>be</span> <span style=''>known</span> <span style=''>ahead</span> <span style=''>of</span> <span style=''>time</span> <span style=''>It</span> <span style=''>is</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>insensitive</span> <span style=''>to</span> <span style=''>the</span> <span style=''>original</span> <span style=''>ordering</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Predicting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>University</span> <span style=''>Students</span> <span style=''>Academic</span> <span style=''>Success</span> <span style=''>and</span> <span style=''>Choice</span> <span style=''>of</span> <span style=''>Major</span> <span style=''>using</span> <span style=''>Random</span> <span style=''>Forests</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style=''>large</span> <span style=''>data</span> <span style=''>set</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>containing</span> <span style=''>every</span> <span style=''>course</span> <span style=''>taken</span> <span style=''>by</span> <span style=''>every</span> <span style=''>undergraduate</span> <span style=''>student</span> <span style=''>in</span> <span style=''>a</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>university</span> <span style=''>in</span> <span style=''>Canada</span> <span style=''>over</span> <span style=''>10</span> <span style=''>years</span> <span style=''>is</span> <span style=''>analyzed</span> <span style=''>Modern</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>can</span> <span style=''>use</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>to</span> <span style=''>build</span> <span style=''>useful</span> <span style=''>tools</span> <span style=''>for</span> <span style=''>the</span> <span style=''>data</span> <span style=''>provider</span> <span style=''>in</span> <span style=''>this</span> <span style=''>case</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>university</span> <span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructed</span> <span style=''>using</span> <span style=''>random</span> <span style=''>forests</span> <span style=''>To</span> <span style=''>begin</span> <span style=''>the</span> <span style=''>first</span> <span style=''>two</span> <span style=''>semesters</span> <span style=''>of</span> <span style=''>courses</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completed</span> <span style=''>by</span> <span style=''>a</span> <span style=''>student</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>if</span> <span style=''>they</span> <span style=''>will</span> <span style=''>obtain</span> <span style=''>an</span> <span style=''>undergraduate</span> <span style=''>degree</span> <span style=''>Secondly</span> <span style=''>for</span> <span style=''>the</span> <span style=''>students</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completed</span> <span style=''>a</span> <span style=''>program</span> <span style=''>their</span> <span style=''>major</span> <span style=''>choice</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicted</span> <span style=''>using</span> <span style=''>once</span> <span style=''>again</span> <span style=''>the</span> <span style=''>first</span> <span style=''>few</span> <span style=''>courses</span> <span style=''>theyve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>registered</span> <span style=''>to</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>tree</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitive</span> <span style=''>and</spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12585155969881678)
# 	architecture (0.08210828253854428)
# 	processing (0.10003585514521333)
# 	experimental (0.13553244890641808)
# 	segmentation (0.07816421656507709)
# 	different (0.2588741484403012)
# 	detection (0.11473646468268196)
# 	information (0.2524202223019003)
# 	convolutional (0.13087128002868412)
# 	recognition (0.1369666547149516)
#
# Some Statistics words are:
# 	stochastic (0.13177523620089507)
# 	algorithm (0.38339134758826454)
# 	estimation (0.17304823470909994)
# 	statistical (0.15266036797613128)
# 	theoretical (0.15464942814520138)
# 	variables (0.14818498259572352)
# 	distribution (0.17802088513177525)
# 	inference (0.19890601690701143)
# 	dimensional (0.19741422178020884)
# 	regression (0.18100447538538042)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="34d23b66-886c-4eea-bed0-f16ed9ee3f78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34d23b66-886c-4eea-bed0-f16ed9ee3f78")) {                    Plotly.newPlot(                        "34d23b66-886c-4eea-bed0-f16ed9ee3f78",                        [{"x":["parameters","intractable","probabilistic","submodular","separable","estimation","interpretations","stochastic","experiments","illustrate","subgradient","parameter","technique","conditional","highlight","optimization","densities","expectation","supermodular","denoising","partition","segmentation","likelihood","variables","flexibility","primarily","combinatorial","distributions","approximation","introduce","feasibility","optimized","recognizing","processing","detection","supervised","detecting","recognizes","challenging","transformer","integrates","recognition","completely","performing","identified","benchmark","competitive","recognize","therefore","documents","technical","experiencing","assessments","supporting","scientific","modelling","phenomenal","particular","currently","automating","techniques","regulations","authoring","industries","regulatory","solutions","optimizations","multiobjective","challenges","different","objective","investigations","procedures","waveforms","algorithms","optimisation","effectiveness","ethnicity","essential","computational","quantitative","comparison","conditions","automatic","knowledge","illumination","adaptable","histogram","qualitative","robustness","efficient","variation","successfully","performance","traditional","information","evaluations","combining","simulations","estimated","heuristic","advantageous","difficult","separately","outperform","implicitly","breakthrough","university","algorithm","programming","convergence","crossover","evolutionary","strategies","manuscript","scenarios","considered","additional","complexity","instances","completeness","alternative","behavioral","unreliable","experimental","contribution","challenge","frameworks","comparatively","processes","contaminated","problematic","artifacts","introduced","versatile","recordings","simulation","generating","correlates","benchmarking","partially","labelings","generalization","assumptions","cognitive","specifically","typically","unrealistic","evaluation","arbitrary","noiseless","facilitating","shortcomings","artificial","available","inventories","experience","situations","regularly","presented","accumulate","effective","relevance","decisions","application","preferences","transport","corresponding","kantorovich","approximates","independent","separation","variational","inference","contributes","increasing","posterior","dimensions","independence","benchmarks","approaches","truncated","posteriors","investigate","applications","independently","saturates","furthermore","distribution","interaction","interchangeability","constraints","symmetries","precedence","comprehensive","generalizations","significantly","demonstrated","establish","numerical","equivalence","classification","implementation","classifier","regularity","minimization","comparable","assumption","consistency","representation","screening","introducing","statistical","suggested","negligible","relatively","computation","acceptance","statistics","comparisons","propagation","performed","simulated","adaptation","laborious","producing","efficiently","approximate","including","consequence","magnitude","constraint","neuroscience","refinements","advantage","crowdsourcing","describing","internally","contributors","dramatically","crowdsourced","annotators","aggregating","reliability","expertise","regression","established","improving","revolutionized","backpropagation","empirically","languages","development","utterance","pre ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	supermodular
# 	seasonality
# 	equitability
# 	straggler
# 	stragglers
# 	heartbeats
# 	electrocardiogram
# 	ensembled
# 	unavailability
# 	implementable
# 	privileged
# 	linearnonlinear
# 	lengthscale
# 	neuroimaging
# 	subroutines
# 	everywhere
# 	missforest
# 	parametrically
# 	bootstrapped
# 	preconditioned
# Some words which never appear in Statistics papers:
# 	transformer
# 	experiencing
# 	phenomenal
# 	authoring
# 	multiobjective
# 	ethnicity
# 	inventories
# 	regularly
# 	interchangeability
# 	precedence
# 	handcrafting
# 	recombination
# 	intrinsics
# 	offloading
# 	concatenation
# 	inapproximability
# 	outbreaks
# 	emergency
# 	encouragingly
# 	syntactic

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.075787401574804e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
